# %% [markdown]
# ## Build Model

# %%
import pandas as pd

df = pd.read_csv("Data\Genshin_Impact.csv",encoding='utf-8')
df.dropna(subset = ["content"], inplace = True)
df.drop_duplicates(keep = "first", inplace = True)
print(str(df.shape[0]) + " comments and their related information are scrapped from Bilibili Game Center.")
df.head()
# Out:
# 256732 comments and their related information are scrapped from Bilibili Game Center.
#    Unnamed: 0             name  level             datetime       content  \
# 0           0   bili_235060966      5  2019-06-07 17:31:06  在？我是第一个预约的吗？
# 1           1      KAMISAMA是阿笑      5  2019-06-07 17:35:17          期待期待
# 2           2            遙かなる夢      5  2019-06-07 17:38:56          来了来了
# 3           3             打倒豆豆      6  2019-06-07 17:46:44         非常的期待
# 4           4  MitsuharuYosaka      5  2019-06-07 17:47:23          好期待啊
#
#    grade  up  down  rcount
# 0      8  21    11       3
# 1     10   6    12       0
# 2      8   5    10       0
# 3     10   5    11       0
# 4     10   5     8       0

# %%
import jieba

extra_words = ["氪金", "骗氪", "白嫖", "零氪", "微氪", "又肝", 
               "米哈游", "米卫兵", "云玩家", "出货率", "圣遗物", "海灯节", 
               "开放世界", "未来可期", "文化输出", "3A大作", "数值膨胀", "喂不饱的狼"]

for word in extra_words:
    jieba.add_word(word, freq = df[df["content"].str.contains(word)].shape[0])
    
df.drop(df[df["content"].str.contains("|".join(["---", "———", "2019", "2020", "2021"]))].index, inplace = True)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\rgdfy\AppData\Local\Temp\jieba.cache
# Loading model cost 0.942 seconds.
# Prefix dict has been built successfully.

# %%
from sklearn.model_selection import train_test_split

test_ratio = 0.2
seed = 123

pos = df[df["grade"] > 6]["content"]
pos_train, pos_test = train_test_split(pos, test_size = test_ratio, random_state = seed, shuffle = True)
textfile = open("Data/pos.txt", "w",encoding='utf-8')
for comment in pos_train:
    textfile.write(comment + "\n")
textfile.close()

neg = df[df["grade"] <= 6]["content"]
neg_train, neg_test = train_test_split(neg, test_size = test_ratio, random_state = seed, shuffle = True)
textfile = open("Data/neg.txt", "w",encoding='utf-8')
for comment in neg_train:
    textfile.write(comment + "\n")
textfile.close()

# %%
from snownlp import sentiment
from snownlp import SnowNLP
from tqdm import tqdm
sentiment.train("Data/neg.txt", "Data/pos.txt")
sentiment.save(r"C:\Users\rgdfy\AppData\Local\Programs\Python\Python38\Lib\site-packages\snownlp\sentiment\sentiment.marshal")
pos_results = [SnowNLP(comment).sentiments for comment in tqdm(pos_test)]
neg_results = [SnowNLP(comment).sentiments for comment in tqdm(neg_test)]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 23672/23672 [05:08<00:00, 76.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 26831/26831 [06:50<00:00, 65.30it/s]

# %%
accuracy = []
thresholds = [i / 1000 for i in range(1001)]
for x in thresholds:
    correct = 0
    for result in pos_results:
        if (result >= x):
            correct += 1
    for result in neg_results:
        if (result < x):
            correct += 1
    accuracy.append(correct / (len(pos_test) + len(neg_test)) * 100)
threhold = accuracy.index(max(accuracy)) / 1000
print("Accuracy: " + str(round(max(accuracy), 2)) + "%")
# Out:
# Accuracy: 79.22%

# %% [markdown]
# ## Apply Model to Video Comments

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from snownlp import sentiment
from snownlp import SnowNLP
from tqdm import tqdm

# %%
df = pd.read_csv("远.csv")
#df.drop("Unnamed: 0", axis = 1, inplace = True)
df.dropna(subset = ["content"], inplace = True)
df.drop_duplicates(keep = "first", inplace = True)
print(str(df.shape[0]) + " comments and their related information are scrapped from Target Video.")
df.head()
# Out:
# 73493 comments and their related information are scrapped from Target Video.
#          rpid        oid        mid       name  level             datetime  \
# 0  5479781237  720739815   24839224   IKEHOSHI      5  2021-09-28 12:00:44
# 1  5479773459  720739815  152431077       晚睡会飘      5  2021-09-28 12:00:46
# 2  5479773554  720739815   37922740  PalpitaZz      5  2021-09-28 12:00:49
# 3  5479781553  720739815  124668951       戰丨星神      5  2021-09-28 12:00:52
# 4  5479777337  720739815  122549284        呆小麻      5  2021-09-28 12:00:52
#
#      content  like  rcount
# 0       ？！刚刚     6       0
# 1      生日快乐呀     2       0
# 2         来了     2       0
# 3  [热词系列_好耶]    15       0
# 4         来咯     4       0

# %%
df["date"] = [t.split(" ")[0] for t in list(df["datetime"])]
df["sentiment"] = [1 if SnowNLP(comment).sentiments >= threhold else -1 for comment in list(df["content"])]

# %% [markdown]
# ### Simple Polarity Analysis

# %%
df
# Out:
#              rpid        oid         mid       name  level  \
# 0      5479781237  720739815    24839224   IKEHOSHI      5
# 1      5479773459  720739815   152431077       晚睡会飘      5
# 2      5479773554  720739815    37922740  PalpitaZz      5
# 3      5479781553  720739815   124668951       戰丨星神      5
# 4      5479777337  720739815   122549284        呆小麻      5
# ...           ...        ...         ...        ...    ...
# 73488  5558684536  720739815    18276592    柠檬果茶四季春      6
# 73489  5559773488  720739815   259453649       宫梼梼梼      4
# 73490  5560831598  720739815   599152125        残夢l      4
# 73491  5563523735  720739815    24568255  Dooglitch      6
# 73492  5566057851  720739815  1067400883       荆棘暮雨      3
#
#                   datetime                                            content  \
# 0      2021-09-28 12:00:44                                               ？！刚刚
# 1      2021-09-28 12:00:46                                              生日快乐呀
# 2      2021-09-28 12:00:49                                                 来了
# 3      2021-09-28 12:00:52                                          [热词系列_好耶]
# 4      2021-09-28 12:00:52                                                 来咯
# ...                    ...                                                ...
# 73488  2021-10-10 09:43:30  自己做的心海MMD，喜欢的求个滋磁！！谢谢！\r\n【「原神·MMD」热爱105°C的心海~...
# 73489  2021-10-10 13:00:15  我觉得很奇怪为什么有人发洗地什么的发色了什么还有什么原不原谅？爷只是个打游戏的官方给爷福利爷...
# 73490  2021-10-10 16:20:04                                           心海剧情....
# 73491  2021-10-10 23:31:12                           原神剧情真tm墨迹 玩这个游戏的人真的是时间多啊
# 73492  2021-10-11 14:41:14                                            逐月符过期是吧
#
#        like  rcount        date  sentiment
# 0         6       0  2021-09-28          1
# 1         2       0  2021-09-28          1
# 2         2       0  2021-09-28         -1
# 3        15       0  2021-09-28          1
# 4         4       0  2021-09-28         -1
# ...     ...     ...         ...        ...
# 73488     2       0  2021-10-10          1
# 73489     0       0  2021-10-10         -1
# 73490     0       1  2021-10-10          1
# 73491     0       2  2021-10-10         -1
# 73492     0       0  2021-10-11         -1
#
# [73493 rows x 11 columns]

# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
df1 = df[(df["date"] >= "2020-12-01") & (df["date"] < "2021-10-07")]

x = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in list(df1["date"].drop_duplicates())]
y1 = df1[df1["sentiment"] == 1].groupby("date")["content"].count().tolist()
y2 = df1[df1["sentiment"] == -1].groupby("date")["content"].count().tolist()

plt.plot(x, y1, label = "pos")
plt.plot(x, y2, label = "neg")
plt.legend(fontsize = 22)
plt.xlabel("Date", fontsize = 22)
plt.ylabel("Number of Comments", fontsize = 22)
plt.show()

# %% [markdown]
# ### Take Number of Likes into Consideration

# %%
df4  = df[(df["date"] >= "2020-12-01") & (df["date"] < "2021-10-07")]

x = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in list(df4["date"].drop_duplicates())]
y = df4.groupby("date")["overall"].sum().tolist()

plt.plot(x, y)
plt.xlabel("Date", fontsize = 22)
plt.ylabel("Overall Daily Attitude", fontsize = 22)
plt.show()

# %% [markdown]
# ### Average User Level

# %%
x = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in list(df4["date"].drop_duplicates())]
s1 = df4[df4["sentiment"] == 1].groupby("date")["level"].sum().tolist()
c1 = df4[df4["sentiment"] == 1].groupby("date")["level"].count().tolist()
y1 = [s1[i] / c1[i] for i in range(len(s1))]
s2 = df4[df4["sentiment"] == -1].groupby("date")["level"].sum().tolist()
c2 = df4[df4["sentiment"] == -1].groupby("date")["level"].count().tolist()
y2 = [s2[i] / c2[i] for i in range(len(s2))]

plt.plot(x, y1, label = "pos")
plt.plot(x, y2, label = "neg")
plt.legend(fontsize = 22)
plt.xlabel('Date', fontsize = 22)
plt.ylabel('Average User Level', fontsize = 22)
plt.show()

# %% [markdown]
# ## 评论最多的15用户

# %%
sentiment_df = df[df['sentiment'] == -1]

# 统计出现次数最多的15个mid
top_15_mids = sentiment_df['mid'].value_counts().head(15)

# 打印 mid 和出现次数及其对应的 content 和 level 值
for mid, count in top_15_mids.items():
    subset = sentiment_df[sentiment_df['mid'] == mid]
    content_values = subset['content'].tolist()
    level_values = subset['level'].tolist()
    x=len(''.join(content_values))
    print(f'mid: {mid}, count: {count},level: {level_values[0]},len:{x}')
    print(f'content: {content_values}')
    print('-------------')
print
# Out:
# mid: 347017144, count: 60,level: 5,len:33853
# content: ['你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??\r\n真的恶心删掉了', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??\r\n转屏被删掉了', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??\r\n转屏被删掉', '月卡到期了，准备溜了', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??\r\n转屏被删掉了', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??\r\n转屏被删掉', '接力来力[OK]\r\n你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气 ...
# -------------
# mid: 343483877, count: 59,level: 4,len:5944
# content: ['抠你是真的抠，周年庆就一个十连？', '抠', '这奖励少的离谱', 'RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！RNM！退钱！', '抠抠抠抠抠抠抠抠抠抠抠', '真的无语，周年庆就这', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的热', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的热评.', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的热评.', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的热评..', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                
'以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？', '他删的实在是太快了', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗（兄弟们接力起来，也希望我们不只是转发，要有实际行动！小氪也改变不了太多结局，还不如不氪白嫖xp）转起来！', '笑死了，刚看到评论想回复，结果被删除了，爷再复制一遍\r\n1.周年庆没送十连，是逐月节的，别做成广告混淆视听（要是杠请翻翻海灯节的10连，海灯节结束了甚至还送了几个球）\r\n2.你是唯一一个周年庆被冲的游戏\r\n3.给11人过周年庆真是谢谢了\r\n4.连个名片都不愿意出\r\n5.能登上福布斯榜的扣不亏是你\r\n6.综上所述，庆周年就一个活动：首充双倍重置\r\nb站消失热评', '笑死了', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗[无语][无语][无语]\r\n（复制的）', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗。', '究竟是怎样的策划让mhy决定周年庆一毛不拔？100抽和100个用户哪个重要？[tv_白眼][tv_白眼][tv_白眼]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '抠死你得了', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '笑死了，刚看到评论想回复，结果被删除了，爷再复制一遍\r\n1.周年庆没送十连，是逐月节的，别做成广告混淆视听（要是杠请翻翻海灯节的10连，海灯节结束了甚至还送了几个球）\r\n2.你是唯一一个周年庆被冲的游戏\r\n3.给11人过周年庆真是谢谢了\r\n4.连个名片都不愿意出\r\n5.能登上福布斯榜的扣不亏是你\r\n6.综上所述，庆周年就一个活动：首充双倍重置\r\nb站消失热评', '喜欢删是吧，转载自消失的转载评论\r\n开服：奖励10抽常驻10抽UP，扣的要命，官方嘲讽不过现实节。大家都说双节还有奖励，结果后来出了一个社区抽奖月卡，大部分玩家全程陪跑....\r\n1.1前瞻直播，钟离巨额伤害欺诈，用原石数量骂玩家250。测底激怒全体玩家，反馈无视，最后发公告声称无问题。\r\n1.2玩家集体冲爆，***，最后被迫才承认有问题，会测试改。\r\n1.3过年，只有10连，为了省声优钱，全程无任何重要人物出场，被玩家怒喷！\r\n1.4被迫无奈，请声优配音，登场几个角色过风花节，不甘心花钱服务玩家，于是扣除10连的原石，成为1.3海灯节的还贷期。\r\n1.5开始尝试空降角色，加满命骗氪，导致尤拉平民玩家体验很差。\r\n1.6唯一一个还算良心些的版本，虽然开始贩卖无特效皮肤，而且价格贵的离谱，虽然开始尝试两命骗氪，开始尝试专武分化角色能力。\r\n2.0开始尝试厨力骗氪，五星强度开始随机性缩水。\r\n2.1剧情开始拉胯，二命一精成为骗氪日常，五星强度开始随机性缩成仓管。明明是一周年，却无任何周年游戏内容，再次10连打发玩家，社区再次抽月卡提纯纯米精灵。\r\n回想这一年，时光过得很快。但有原神的陪伴，平凡的日子也闪烁着稀碎的刚复制的[打call]继续删', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你好意思乱花钱么\r\n（原热评第一，现已被删除）', '恶不恶心啊', '直接无视玩家，自己做自己的游戏，看你能活多久', '光骂没用，你不氪我不氪米哈游明天就道歉', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你好意思乱花钱么\r\n（原热评第一，现已被删除）', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '哇，突然想到一个很恐怖的事情，以后神里每年都要在这个晦气的日子过生日[笑哭]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你好意思乱花钱么\r\n（原热评第一，现已被删除）', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的
'多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n消失的热评[呲牙]', '骂抠真的没用[无语]他们是资本家是以利益为首的，这样骂他抠除了过嘴瘾根本造成不了什么实质性的伤害，除非停氪让他赚不到钱[无语]赚不到钱的时候才会真正讨好玩家的，如果还是一边冲一边给他送钱[无语]我要是官方我也不理[无语]\r\n转', '当下想吃的那份菜没吃到 就算换成其他东西 也怎么都弥补不了那种情绪  后续再怎么补救终归有根刺在那里', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                      ————转已消失的热评', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                      ————转已消失的热评[无语][无语]', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                      ————转已消失的热评[无语][无语]', '是不是我们真的太贪心了？于是今天我调整了心态开始玩原神。\r\n锄大地时我爆了蓝面具。众所周知蓝面具＝3绿面具＝45尘辉＝3抽的副产物。即使是副产物也足显米哈游的慷慨，于是我原地跪下跪了五分钟。以此类推绿面具就是一抽的副产物。也有相当的价值，由于锄地爆率还不错，我把桌子腿全锯了方便我一直跪在地上玩游戏也能够到电脑。\r\n走到半路发现了以前漏了的箱，开箱得了2原石，原石是付费代币，付费代币等于人民币，这是米哈游在慷慨的给我发钱，我一时难忍激动，当场给米哈游了磕个头。\r\n开了esc菜单发现昨天邮件没领，点开就是100原石，100原石！我要开50个箱子！就是需要我磕50个头！我觉得单纯磕头已经不能表达我的感激了，于是我沐浴更衣给米哈游上了香郑重的磕了三个头。\r\n凌晨来了，一封新的邮件。200原石！！！！！！！！！？！200！！！！！我从未想到米哈游能这么慷慨！算上前4天加起来一共达到了700原石！！米哈游非亲非故的白送了我70元，然后我又转念一想，打开了米游社手账，发现我以前的原石收益竟然有好几万。这表示米哈游，白送了我好几千人民币！然后我一时气血上涌晕了过去。\r\n我舍友给我打的120，而我现在是躺在急救病床上，医生说我大概熬不过今晚了，但我临走之前一定要把我对米哈游的感激之情表达出来。', '是不是我们真的太贪心了？于是今天我调整了心态开始玩原神。\r\n锄大地时我爆了蓝面具。众所周知蓝面具＝3绿面具＝45尘辉＝3抽的副产物。即使是副产物也足显米哈游的慷慨，于是我原地跪下跪了五分钟。以此类推绿面具就是一抽的副产物。也有相当的价值，由于锄地爆率还不错，我把桌子腿全锯了方便我一直跪在地上玩游戏也能够到电脑。\r\n走到半路发现了以前漏了的箱，开箱得了2原石，原石是付费代币，付费代币等于人民币，这是米哈游在慷慨的给我发钱，我一时难忍激动，当场给米哈游了磕个头。\r\n开了esc菜单发现昨天邮件没领，点开就是100原石，100原石！我要开50个箱子！就是需要我磕50个头！我觉得单纯磕头已经不能表达我的感激了，于是我沐浴更衣给米哈游上了香郑重的磕了三个头。\r\n凌晨来了，一封新的邮件。200原石！！！！！！！！！？！200！！！！！我从未想到米哈游能这么慷慨！算上前4天加起来一共达到了700原石！！米哈游非亲非故的白送了我70元，然后我又转念一想，打开了米游社手账，发现我以前的原石收益竟然有好几万。这表示米哈游，白送了我好几千人民币！然后我一时气血上涌晕了过去。\r\n我舍友给我打的120，而我现在是躺在急救病床上，医生说我大概熬不过今晚了，但我临走之前一定要把我对米哈游的感激之情表达出', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge][doge]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n（持续接力中）', '做什么广告，名声那么臭，福利那么扣，角色那么弱，卡池那么深[无语]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n（另外，外网也炸了：你他喵周年庆就给我们看个广告？没别的了？？？！！）', '做什么广告，名声那么臭，福利那么扣，角色那么弱，卡池那么深', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                      ————转已消失的热评[辣眼睛][辣眼睛][辣眼睛][辣眼睛]', '我就想问你这周年庆过的不尬吗[辣眼睛][辣眼睛]', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                      ————转已消失的热评', '别冲了，冲不动的，你在这里说福利小只会被别人当做魔怔人，当猴当米黑看，三蹦子不是最好的例子么，官方会稀罕老玩家？爱停氪停氪，爱退坑退坑，听不进去的', '别冲了，冲不动的，你在这里说福利小只会被别人当做魔怔人，当猴当米黑看，三蹦子不是最好的例子么，官方会稀罕老玩家？爱停氪停氪，爱退坑退坑，听不进去的      一周年两手空空三十原石限量四海皆知五体投地；\r\n十连抽九把武器八十保底还歪七七命座六的飞起；\r\n横批：格局   为什么热评都是几分钟十几分钟的，心里没点数吗原神？？？？？[怪我咯]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]..', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]..，', '今天是周年庆 准备去找个福利 这里链接20个原石 那里链接30个原石 然后又蹦出来什么链接又有原石 这里一点那里一点 忙活完了一看 哎呀 连个十连都凑不够 只觉得mhy送我的一抽真大方[大哭][大哭][大哭]', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线 ...
# -------------
# mid: 50191858, count: 37,level: 5,len:106
# content: ['抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', 'mhy已经不是小厂了，听不到我们玩家的声音了', '抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', '抠门', '抠', 'ex自己玩家有一手，周年庆这么抠', '抠', '抠门', '抠门', '抠', '抠门', '抠', '抠门', '抠', '抠门', '奖励扣扣搜搜的小厂作风', '失去玩家对你的好感', '抠', '烂']
# -------------
# mid: 443966044, count: 35,level: 4,len:5852
# content: ['喜欢删是吧，转载自消失的转载评论\r\n开服：奖励10抽常驻10抽UP，扣的要命，官方嘲讽不过现实节。大家都说双节还有奖励，结果后来出了一个社区抽奖月卡，大部分玩家全程陪跑....\r\n1.1前瞻直播，钟离巨额伤害欺诈，用原石数量骂玩家250。测底激怒全体玩家，反馈无视，最后发公告声称无问题。\r\n1.2玩家集体冲爆，***，最后被迫才承认有问题，会测试改。\r\n1.3过年，只有10连，为了省声优钱，全程无任何重要人物出场，被玩家怒喷！\r\n1.4被迫无奈，请声优配音，登场几个角色过风花节，不甘心花钱服务玩家，于是扣除10连的原石，成为1.3海灯节的还贷期。\r\n1.5开始尝试空降角色，加满命骗氪，导致尤拉平民玩家体验很差。\r\n1.6唯一一个还算良心些的版本，虽然开始贩卖无特效皮肤，而且价格贵的离谱，虽然开始尝试两命骗氪，开始尝试专武分化角色能力。\r\n2.0开始尝试厨力骗氪，五星强度开始随机性缩水。\r\n2.1剧情开始拉胯，二命一精成为骗氪日常，五星强度开始随机性缩成仓管。明明是一周年，却无任何周年游戏内容，再次10连打发玩家，社区再次抽月卡提纯纯米精灵。\r\n回想这一年，时光过得很快。但有原神的陪伴，平凡的日子也闪烁着稀碎的刚复制的[打call]继续删请继续\r\n\r\n                                        (接力C，复制转载)', '喜欢删是吧，转载自消失的转载评论\r\n开服：奖励10抽常驻10抽UP，扣的要命，官方嘲讽不过现实节。大家都说双节还有奖励，结果后来出了一个社区抽奖月卡，大部分玩家全程陪跑....\r\n1.1前瞻直播，钟离巨额伤害欺诈，用原石数量骂玩家250。测底激怒全体玩家，反馈无视，最后发公告声称无问题。\r\n1.2玩家集体冲爆，***，最后被迫才承认有问题，会测试改。\r\n1.3过年，只有10连，为了省声优钱，全程无任何重要人物出场，被玩家怒喷！\r\n1.4被迫无奈，请声优配音，登场几个角色过风花节，不甘心花钱服务玩家，于是扣除10连的原石，成为1.3海灯节的还贷期。\r\n1.5开始尝试空降角色，加满命骗氪，导致尤拉平民玩家体验很差。\r\n1.6唯一一个还算良心些的版本，虽然开始贩卖无特效皮肤，而且价格贵的离谱，虽然开始尝试两命骗氪，开始尝试专武分化角色能力。\r\n2.0开始尝试厨力骗氪，五星强度开始随机性缩水。\r\n2.1剧情开始拉胯，二命一精成为骗氪日常，五星强度开始随机性缩成仓管。明明是一周年，却无任何周年游戏内容，再次10连打发玩家，社区再次抽月卡提纯纯米精灵。\r\n回想这一年，时光过得很快。但有原神的陪伴，平凡的日子也闪烁着稀碎的刚复制的[打call]继续删请继续\r\n\r\n                                        (接力C，复制转载)', '评论2.4w 最高攒也才1千多 这手删评我愿称其为最强', '喜欢删是吧，转载自消失的转载评论\r\n开服：奖励10抽常驻10抽UP，扣的要命，官方嘲讽不过现实节。大家都说双节还有奖励，结果后来出了一个社区抽奖月卡，大部分玩家全程陪跑....\r\n1.1前瞻直播，钟离巨额伤害欺诈，用原石数量骂玩家250。测底激怒全体玩家，反馈无视，最后发公告声称无问题。\r\n1.2玩家集体冲爆，***，最后被迫才承认有问题，会测试改。\r\n1.3过年，只有10连，为了省声优钱，全程无任何重要人物出场，被玩家怒喷！\r\n1.4被迫无奈，请声优配音，登场几个角色过风花节，不甘心花钱服务玩家，于是扣除10连的原石，成为1.3海灯节的还贷期。\r\n1.5开始尝试空降角色，加满命骗氪，导致尤拉平民玩家体验很差。\r\n1.6唯一一个还算良心些的版本，虽然开始贩卖无特效皮肤，而且价格贵的离谱，虽然开始尝试两命骗氪，开始尝试专武分化角色能力。\r\n2.0开始尝试厨力骗氪，五星强度开始随机性缩水。\r\n2.1剧情开始拉胯，二命一精成为骗氪日常，五星强度开始随机性缩成仓管。明明是一周年，却无任何周年游戏内容，再次10连打发玩家，社区再次抽月卡提纯纯米精灵。\r\n回想这一年，时光过得很快。但有原神的陪伴，平凡的日子也闪烁
色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                                       ————转已消失的热评', '作为一个快57级的老玩家，这大半年来投入的感情有多少，现在就有多少失望\r\n曾经在1.5、1.6时感受到自己的反馈最终落实到游戏内容里是真的很开心，当时很天真的以为这个游戏会越来越好\r\n但是你们2.1的操作真的是太难看了\r\n我很难否认你们在大招地图和角色上有着独特的魅力，这也是我一直玩下去的原因\r\n但是你们现在的操作真的太难看了\r\n我觉得玩家们也许真的是被心海这一波操作搞到全体脑溢血，以至于2.1主线后半段的稀烂都没人提了，在能用到自己建模天然优势的情况下，能把一场战争描述的这么儿戏这么无聊真的是完完全全的败笔，而你们更大的败笔就是把你们以前优势的人物设计的质量都搞得拉胯，宵宫完全没有配合的呆板技能组设计，心海拉胯到极致的强度不说水上行走这种对平衡性根本没影响的机制都得砍到大招的里，合着我tm为了想带着自己的现人神花瓶去水上散散步还得去给她打个70能量，我tmd不缺强度，但你好歹要给我一个抽出来以后能我觉得游戏里面玩到会快乐的角色，这应该是你们做一个角色出来最低最低最低的底线了吧？我要是只为了看她好看，我点开个视频行不行吗？建议贵公司给心海接个降压药的商单，我花了钱抽了个让我飙血压的角色，再花钱去买给自己买你们代言的降压药是不是帮你们完成了资金循环？\r\n再说说卡池问题，从开始玩到现在我都觉得这个沙币up池和沙币常驻池的设定沙币到离谱，更不要提这个限定20天的up池还tmd只有50概率，我最高一次连着五次大保底你知道我有多tm难受吗，而且大保底就算了，要不你让我选一选我歪了能换个啥也行，这倒好，玩到57级抽不到刻晴和琴，给我个抽不到up池的安慰是不是能要你的命？再说说池子里的四星，抽了大半年搞得我能抽到的四星已经有九个满命的，每次池子保底一个经常两个满命四星，合着我每抽十抽运气不好就再多送我一抽？这五个星辉换一个纠缠之缘真的是人想出来的吗？我玩一个月攒的六十抽要是歪了换来的就是再抽几发？恶心人要有个限度可以吗？up池50概率动不动就歪，歪了连我想歪的角色抽不到，原石不够下一次角色up半年后，贵游这么喜欢逼氪所以周年庆给我十个石头好打发我让我继续氪金是吗？\r\n转', '崩坏三的老路可不可取我觉得你们多少心里也清楚吧，当回人真的有这么难吗？你随便拉个大街上的路人来当编剧和周年庆策划都比你们现在那群吃干饭的好的多，次次都要靠美术和音乐来拖着其他方面走真的不会有一点点害臊的吗？就原神这个游戏，当初出来的时候你的那些玩家玩到现在的你知道受过多少委屈？还处处维护你，试图解释你的优点，玩家想过一个像样子点的周年庆就这么难吗？提纯是吧，我看你这么作下去提纯剩下的估计就只剩一群nc粉，跟捏马一个白眼狼一样', '你愿意为了首充重置而特意发个公告来提醒，却不愿意在周年庆的当天发邮件祝我们快乐。\r\n你愿意出周边，出up，出198音乐会礼包，却不愿意给我们一个周年庆的小纪念品。\r\nMHY！\r\nRNM！！\r\n退钱！！！', '骂抠真的没用[无语]他们是资本家是以利益为首的，这样骂他抠除了过嘴瘾根本造成不了什么实质性的伤害，除非停氪让他赚不到钱[无语]赚不到钱的时候才会真正讨好玩家的，如果还是一边冲一边给他送钱[无语]我要是官方我也不理[无语]\r\n转', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]', '你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代??', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节 ...
# -------------
# mid: 1857266550, count: 34,level: 3,len:9254
# content: ['继续删啊\r\n我猜删掉这条评论会在10分钟内\r\nmhy你又一次泼了老玩家冷水，好多人都点赞见过了我这个评论，我再发一遍《你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n周年如果真的就那十抽，我和我拉来的五个朋友达成共识了，如果真就那破十抽，那就再见了，不会犹豫的\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代\r\n（转自被删评）\r\n咋，刚想点赞，就被删了\r\n接力', '继续删啊\r\n我猜删掉这条评论会在10分钟内\r\nmhy你又一次泼了老玩家冷水，好多人都点赞见过了我这个评论，我再发一遍《你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n周年如果真的就那十抽，我和我拉来的五个朋友达成共识了，如果真就那破十抽，那就再见了，不会犹豫的\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代\r\n（转自被删评）\r\n咋，刚想点赞，就被删了', '开服黑暗降临时代  策划装死\r\n钟离事件                策划装死\r\n永久的刻晴问题     策划装死\r\n宵宫，心海事件     策划装死\r\n一周年大接力事件 策划装死\r\n事情的真相只有一个，那就是策划真的死了[doge]', '官方承诺https://b23.tv/6axrRY ，钟离事件之后你对玩家的承诺去哪里了？米哈游？“在未来的版本中，我们还会根据分析结果持续评估和打磨，让每一位旅行者喜爱的角色都有发挥能力的舞台，还请各位旅行者继续保持耐心等待。”这段话现在看来不就是个笑话？钟离事件一周年复刻是吧？这次忍耐，就会有下次，，下下次，周而复始，看到的兄弟们复制出去，让更多人看到\r\n这个是我刚看到的，删一次发一次，不要怕嘛，不就说了个实话嘛', '开服黑暗降临时代  策划装死\r\n钟离事件                策划装死\r\n永久的刻晴问题     策划装死\r\n宵宫，心海事件     策划装死\r\n一周年大接力事件 策划装死\r\n事情的真相只有一个，那就是策划真的死了[doge]', '继续删啊\r\n我猜删掉这条评论会在10分钟内\r\nmhy你又一次泼了老玩家冷水，好多人都点赞见过了我这个评论，我再发一遍《你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\n周年如果真的就那十抽，我和我拉来的五个朋友达成共识了，如果真就那破十抽，那就再见了，不会犹豫的\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代\r\n（转自被删评）\r\n咋，刚想点赞，就被删了\r\n接力', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '继续删啊\r\n我猜删掉这条评论会在10分钟内\r\nmhy你又一次泼了老玩家冷水，好多人都点赞见过了我这个评论，我再发一遍《你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你 ...
# -------------
# mid: 36964257, count: 33,level: 5,len:5599
# content: ['你会为了首充重置特地发邮件提醒，但你却不肯在一周年当天发邮件庆祝。\r\n————来自一条被删的热评', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)', '我星星你个星星，周年庆一个活动也没有[微笑]，我彎??', '釼????', '太失望了，我星星你个星星', '冲烂你', '自己做大就飘了', '周年庆一点活动也没有', '冲', '玩了这么就，周年庆一个活动也没有，就一个PPT动画，彎??', '冲', '我们要活动', '我要奖励', '这样比任何攻略有用亲测\r\n转载，原帖来自米游社用户空山和雲\r\n在微信，支付宝找出具体的充值消费记录。以微信举例:\r\n1.点击“钱包”,然后点击右上角“账单”\r\n2.进入账单后，点击右上角右.上角“统计”\r\n3.进入统计界面后,下拉,在“支出排行榜”内找到“miHoYo games“这一选项, 点进去就可以看见进一年来在米哈游的消费记录\r\n4.点击每一笔记录,然后截图，截图完成后,去QQ加崩坏三官方客服,客服QQ号:800189596\r\n加完之后,跟他要求开花票,然后把你的游戏id,电子邮箱,消费记录截图发给他(一定是单笔订单的截图）这时候他肯定会给你开电子花票,不慌,跟他要纸质的(作为消费者,根据消费者法规,我们有权利选择罚瞟形式),同时一定要说明白,每笔订单都单独开一张花票。\r\n放心,米哈游不会真给你开的,如果有足够多的玩家同时要求开纸质花票，他真给开了能累死他\r\n这时候不慌，直接打ns服务热线，电话号:021-12366\r\n然后按1-4-4即可人工服务,可能要排队耐心等等(注意,米哈游上海公司一定要打上上海的区号021)\r\n步骤二:人工服务直接投诉不给开花p\r\n步骤三:提供mihoyo相关信息地址和公司全名(上海米哈游影铁科技有限公司，上海市嘉定区银翔路655号1幢11层1101室)\r\n步骤四:等(3-10个工作日)\r\n只要投诉人数超过一定数量gsj就会给mihoyo打电话督促花p的发放\r\n这时候我们的目的就打成了,如果真的有足够多的人参与,ch绝对会妥协,而不是像曾经那样删帖控评,置之不理。\r\n这时候,停止施压。大功告成\r\n重复重点:\r\n 1.定要求开纸质花票!2.定要打ns服务热线! 来自评论转载 \r\n 2.补充一下：有发票的小伙伴用支付宝搜索发票管家，然后点发票摇奖输入发票信息就可以参与税务总局抽奖活动，你们要是中了50万记得给我点赞一下。', '这样比任何攻略有用亲测\r\n转载，原帖来自米游社用户空山和雲\r\n在微信，支付宝找出具体的充值消费记录。以微信举例:\r\n1.点击“钱包”,然后点击右上角“账单”\r\n2.进入账单后，点击右上角右.上角“统计”\r\n3.进入统计界面后,下拉,在“支出排行榜”内找到“miHoYo games“这一选项, 点进去就可以看见进一年来在米哈游的消费记录\r\n4.点击每一笔记录,然后截图，截图完成后,去QQ加崩坏三官方客服,客服QQ号:800189596\r\n加完之后,跟他要求开花票,然后把你的游戏id,电子邮箱,消费记录截图发给他(一定是单笔订单的截图）这时候他肯定会给你开电子花票,不慌,跟他要纸质的(作为消费者,根据消费者法规,我们有权利选择罚瞟形式),同时一定要说明白,每笔订单都单独开一张花票。\r\n放心,米哈游不会真给你开的,如果有足够多的玩家同时要求开纸质花票，他真给开了能累死他\r\n这时候不慌，直接打ns服务热线，电话号:021-12366\r\n然后按1-4-4即可人工服务,可能要排队耐心等等(注意,米哈游上海公司一定要打上上海的区号021)\r\n步骤二:人工服务直接投诉不给开花p\r\n步骤三:提供mihoyo相关信息地址和公司全名(上海米哈游影铁科技有限公司，上海市嘉定区银翔路655号1幢11层1101室)\r\n步骤四:等(3-10个工作日)\r\n只要投诉人数超过一定数量gsj就会给mihoyo打电话督促花p的发放\r\n这时候我们的目的就打成了,如果真的有足够多的人参与,ch绝对会妥协,而不是像曾经那样删帖控评,置之不理。\r\n这时候,停止施压。大功告成\r\n重复重点:\r\n 1.定要求开纸质花票!2.定要打ns服务热线! 来自评论转载 \r\n 2.补充一下：有发票的小伙伴用支付宝搜索发票管家，然后点发票摇奖输入发票信息就可以参与税务总局抽奖活动，你们要是中了50万记得给我点赞一下。[气愤][气愤]', '(来删了爸爸的评论）多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评(接力接力)', 'mhy：一群喂不饱的狼，看我今年喂都不喂，饿死你，看你怎么叫[藏狐]', '没有补上活动，就退游', '继续删啊\r\n我猜删掉这条评论会在10分钟内\r\nmhy你又一次泼了老玩家冷水，好多人都点赞见过了我这个评论，我再发一遍《你原神的玩家这一年多委屈你又不是不知道，你玩的“原来你也玩原神”的梗，从哪来的你也很清楚，大家为什么不告诉别人自己玩原神反而需要别人惊讶的发现？因为你原神名声不好！你原神的玩家根本不敢说自己玩原神！懂吗？是，你也委屈，你觉得自己不该名声恶臭，你觉得是金子总会发光，但是你原神的玩家让你委屈了吗？大家都在陪着你挨骂！大家都在保护你，你不会不知道！后来你节奏弱了，大家开始找你提意见，你觉得提意见这事让你委屈了吗？为什么提意见？想让你死的人根本不会管你烂成什么狗样。你知道为什么提意见的人语气都这么不好吗？你原神p都不放，像个死人似的，装聋作哑，和玩家搞这么大的隔阂，谁会忍住跟你细声细语跟你和平交流？你对得起大家吗？\r\n是，你们的线下活动很丰富，不少，但是你觉得大家有几个能感受你原神弄的活动？有几个能感到和你的0距离接触？没用，搞这些花里胡哨的真不叫什么嘉年华，更不叫什么玩家和你们的友好氛围！\r\n想想也真是笑话，二创比官方积极真是头一次见，不管你们有没有参与这生日会，你游戏里p都没有就是p都没有，没有周年庆的味就是没有！你知不知道你的玩家现在开始转其他游戏了？十分钟下线，真没什么意思，再加上你所谓的一周年，一杯冷水豁头上，陪你走过的一年仿佛没有任何可以纪念的，高开低走形容你最贴切了。你认为你再摆烂大家也离不开你，好多年前你也是这样的态度，真是“不忘初心”啊\r\n一个周年翅膀名片你都不舍得给，你能损失什么啊？天天给点蚊子腿，你能赚到什么啊？真是服了\r\
'以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)[doge]', '还是那句话，只有流水下去了，有些人才明白谁是谁的衣食父母[哈欠]', '是不是点赞超过2000就自动删评啊！测试一下是不是机器人，兄弟们顶我上去[doge][doge]', '你愿意为了首充重置而特意发个公告来提醒，却不愿意在周年庆的当天发邮件祝我们快乐。\r\n你愿意出周边，出up，出198音乐会礼包，却不愿意给我们一个周年庆的小纪念品。\r\n转自已消失的评论', '周年庆真是热闹啊，玩家排着队跟策划御前决斗', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉 ...
# -------------
# mid: 238134699, count: 32,level: 5,len:12028
# content: ['兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。（接力谢谢）', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。\r\n持续接力', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。', '现在突然有点怀念以前的百万水军，当时那样的节奏至少让原神还是有点忌惮害怕，努力做好游戏，发放大量奖励，还有多少人记得当时原神拿奖感谢大家发了1600原石，原神现在没有一点压力，而且随着时间推移水军和猴越来越少，我不是说越来越少不好。就连仅存的一点压力都没有了，原神现在是毫无竞争压力，已经开始在剧情和一些地方不走心了!!水能载舟，亦能覆舟。大家加油好好让原神看看玩家的决心，你要是不好好做，甚至在该有福利的时候不发，就休想从我们这里拿走一分钱![再见][再见][再见]宝，都是玩家的情绪啊[辣眼睛]那有什么节奏？\r\n它会为了首充重置特地发邮件提醒，却不肯在一周年当天发邮件庆祝。\r\n\r\n以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n\r\n之前看过一个采访某游戏ch的视频，ch本人亲自说的：“所有ch就是为了从玩家口袋赚更多的钱，所以也没什么互相理不理解的，这就是我的工作。“ \r\n还有一段“ch就是要试探玩家的底线啊。对ch来说，多给玩家送一个十连，那大概率就会少一个十连的氪金量，所以一般ch会准备好几套方案，先给出一个最低的值，玩家要是觉得可以，那就按那个来，之后还可以继续试探，玩家要是不同意，那也就是把原本准备的方案放出来。一步一步的为了从玩家那弄到更多钱。”\r\n还有一段最离谱的“ch就是做各种不同样子的屎给玩家吃，然后一堆玩家还会为此买账，那躺着能赚钱为啥要站着赚。”\r\n\r\n角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n                                    ———已消失的热评 整合版', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。\r\n持续接力', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。\r\n持续接力', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个好看的角色做点好剧情谁不上头氪十几个648。他怕的是做再好。没人看。再美的角色没人看才是真的没人氪金。而且日活这种东西是按天计算。氪金怕不是按版本计算。到时候策划写报告。我们这个季度赚了多少多少(雷神池子)。一样风光无限。只有玩家流失才是真正的大问题。赚钱少了太多借口可以搪塞了。比如雷神池用力过猛之类的。', '兄弟萌。一星期不上游戏。比什么都强。或者减少在线时间。搞完就跑。是游戏都会统计日活的。原神估计想着到时候出个
'以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你好意思乱花钱么\r\n（原热评第一，现已被删除）', '其实我也不在乎送几抽，毕竟就原神这概率，十抽二十抽的差别不大。但既然是周年庆，总得给点什么有意义的吧。。。\r\n然而名片翅膀全没有，十抽是逐月节 ...
# -------------
# mid: 128471057, count: 31,level: 3,len:1917
# content: ['消失的热评真热闹啊', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金\r\n....', '喜欢删是吧，转载自消失的转载评论\r\n开服：奖励10抽常驻10抽UP，扣的要命，官方嘲讽不过现实节。大家都说双节还有奖励，结果后来出了一个社区抽奖月卡，大部分玩家全程陪跑....\r\n1.1前瞻直播，钟离巨额伤害欺诈，用原石数量骂玩家250。测底激怒全体玩家，反馈无视，最后发公告声称无问题。\r\n1.2玩家集体冲爆，***，最后被迫才承认有问题，会测试改。\r\n1.3过年，只有10连，为了省声优钱，全程无任何重要人物出场，被玩家怒喷！\r\n1.4被迫无奈，请声优配音，登场几个角色过风花节，不甘心花钱服务玩家，于是扣除10连的原石，成为1.3海灯节的还贷期。\r\n1.5开始尝试空降角色，加满命骗氪，导致尤拉平民玩家体验很差。\r\n1.6唯一一个还算良心些的版本，虽然开始贩卖无特效皮肤，而且价格贵的离谱，虽然开始尝试两命骗氪，开始尝试专武分化角色能力。\r\n2.0开始尝试厨力骗氪，五星强度开始随机性缩水。\r\n2.1剧情开始拉胯，二命一精成为骗氪日常，五星强度开始随机性缩成仓管。明明是一周年，却无任何周年游戏内容，再次10连打发玩家，社区再次抽月卡提纯纯米精灵。\r\n回想这一年，时光过得很快。但有原神的陪伴，平凡的日子也闪烁着稀碎的刚复制的[打call]继续删请继续\r\n\r\n                                        (接力C，复制转载)', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗!!!屮', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗!!!屮', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金1', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金2', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金3', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金4', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金1', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金5', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金6', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金7', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金9', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金0', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金1', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金2', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金3', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金4', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金5', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金', '角色平衡我唯唯诺诺\r\n有利bug我重拳出击\r\n原石奖励我扣扣搜搜\r\n广告宣传我一掷千金2', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？1', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？3']
# -------------
# mid: 178985575, count: 31,level: 5,len:4445
# content: ['以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗.', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗.', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗.', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗.', '你会为了首充重置特地发邮件提醒，但你却不肯在一周年当天发邮件庆祝。\r\n————来自一条被删的热评', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗\r\n接力下去', '1.周年庆没送十连，是逐月节的，别做成广告混淆视听（要是杠请翻翻海灯节的10连，海灯节结束了甚至还送了几个球）\r\n2.你是唯一一个周年庆被冲的游戏\r\n3.给11人过周年庆真是谢谢了\r\n4.连个名片都不愿意出\r\n5.能登上福布斯榜的扣不亏是你\r\n6.综上所述，庆周年就一个活动：首充双倍重置\r\nb站消失热评', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，
天给点蚊子腿，你能赚到什么啊？真是服了\r\n周年如果真的就那十抽，我和我拉来的五个朋友达成共识了，如果真就那破十抽，那就再见了，不会犹豫的\r\n大家都是二次元，不信谁喜欢的角色能数清的，别感觉你创造的角色多么能粘住人，你放心，人家弄的人设可比你原神弄的强多了\r\n还有，游戏领域里，你干不过的人多着呢，千万别觉得自己无可替代\r\n（转自被删评）\r\n咋，刚想点赞，就被删了\r\n接力', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你好意思乱花钱么\r\n（原热评第一，现已被删除）', '以后充648的时候我希望大家冷静的想一想，收入这么高的MHY都这么节省，你那点微薄收入好意思乱花钱吗？\r\n(持续接力中)', '多想想怎么留住老玩家吧，周年庆纪念的东西一个没有就一个十连还是东拼西扣的，行吧，没意见，但翅膀家居名片一个没有，真觉得都是想要那几颗原石吗，遗留的老问题一大堆，刻晴设计缺陷强度不理想，七七命座零提升，宵宫空箭，现在心海人设也搞崩了强度还没有，虽然玩家一直在骂，但该夸你的时候一点不会吝啬，ch一次次犯病，犯病干了破事就装死，什么坑都扔给玩家去填，玩家不是圣人，真觉得玩家好糊弄吗？陪你一年时间，刚开始玩个原神跟地下党一样，后面你也争气了，用质量打了它们脸，玩家也开始集合找团体同时给你们反应出现的问题，但除了钟离那次装死没成功，其他时候还是给装死糊弄过去了，玩家要的是你的态度，憋?装死了，多听听玩家的诉求，再装死老玩家真的心凉了【原神_吃惊】\r\n转自 消失的热评', '官方承诺https://b23.tv/6axrRY ，钟离事件之后你对玩家的承诺去哪里了？米哈游？“在未来的版本中，我们还会根据分析结果持续评估和打磨，让每一位旅行者喜爱的角色都有发挥能力的舞台，还请各位旅行者继续保持耐心等待。”这段话现在看来不就是个笑话？钟离事件一周年复刻是吧？这次忍耐，就会有下次，，下下次，周而复始，看到的兄弟们复制出去，让更多人看到\r\n这个是我刚看到的，删一次发一次，不要怕嘛，不就说了个实话嘛', '这样比任何攻略有用亲测\r\n转载，原帖来自米游社用户空山和雲\r\n在微信，支付宝找出具体的充值消费记录。以微信举例:\r\n1.点击“钱包”,然后点击右上角“账单”\r\n2.进入账单后，点击右上角右.上角“统计”\r\n3.进入统计界面后,下拉,在“支出排行榜”内找到“miHoYo games“这一选项, 点进去就可以看见进一年来在米哈游的消费记录\r\n4.点击每一笔记录,然后截图，截图完成后 ...
# -------------
# <function print>

# %% [markdown]
# ## 负面词云

# %%
sentiment_df = df[df['sentiment'] == -1]
from wordcloud import WordCloud

# 统计出现次数最多的15个mid
sentiment_df = df[df['sentiment'] == -1]

# 统计出现次数最多的15个mid
top_15_mids = sentiment_df['mid'].value_counts().head(3544)

# 汇总所有选定mid的content值
all_content = []
for mid in top_15_mids.index:
    content_values = sentiment_df[sentiment_df['mid'] == mid]['content'].tolist()
    all_content.extend(content_values)

# 将所有content值连接成一个字符串，同时移除换行符和多余空格
text = ' '.join(all_content).replace('\n', ' ').replace('\r', ' ').strip()

# 使用 jieba 分词
words = jieba.lcut(text)

# 加载停用词表
with open('hit_stopwords.txt', 'r', encoding='utf-8') as file:
    stopwords = set(file.read().splitlines())

# 去除停用词
words = [word for word in words if word not in stopwords and len(word.strip()) > 0]

# 使用 pandas 计算每个词的频率
word_freq = pd.Series(words).value_counts()

# 生成词云
wordcloud = WordCloud(width=800, height=400, font_path='simhei.ttf', background_color='white').generate_from_frequencies(word_freq)

# 显示词云
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 关闭坐标轴
plt.show()

# %%
word_freq.head(10)

# %% [markdown]
# ## 正面词云

# %%
from wordcloud import WordCloud

# 统计出现次数最多的15个mid
sentiment_df = df[df['sentiment'] == 1]

# 统计出现次数最多的15个mid
top_15_mids = sentiment_df['mid'].value_counts().head(3544)

# 汇总所有选定mid的content值
all_content = []
for mid in top_15_mids.index:
    content_values = sentiment_df[sentiment_df['mid'] == mid]['content'].tolist()
    all_content.extend(content_values)

# 将所有content值连接成一个字符串，同时移除换行符和多余空格
text = ' '.join(all_content).replace('\n', ' ').replace('\r', ' ').strip()

# 使用 jieba 分词
words = jieba.lcut(text)

# 加载停用词表
with open('hit_stopwords.txt', 'r', encoding='utf-8') as file:
    stopwords = set(file.read().splitlines())

# 去除停用词
words = [word for word in words if word not in stopwords and len(word.strip()) > 0 ]

# 使用 pandas 计算每个词的频率
word_freq = pd.Series(words).value_counts()

# 生成词云
wordcloud = WordCloud(width=800, height=400, font_path='simhei.ttf', background_color='white',max_words=100).generate_from_frequencies(word_freq)

# 显示词云
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 关闭坐标轴
plt.show()

# %% [markdown]
# ## 总词云

# %%
from wordcloud import WordCloud

# 统计出现次数最多的15个mid
sentiment_df = df

# 统计出现次数最多的15个mid
top_15_mids = sentiment_df['mid'].value_counts().head(4544)

# 汇总所有选定mid的content值
all_content = []
for mid in top_15_mids.index:
    content_values = sentiment_df[sentiment_df['mid'] == mid]['content'].tolist()
    all_content.extend(content_values)

# 将所有content值连接成一个字符串，同时移除换行符和多余空格
text = ' '.join(all_content).replace('\n', ' ').replace('\r', ' ').strip()

# 使用 jieba 分词
words = jieba.lcut(text)

# 加载停用词表
with open('hit_stopwords.txt', 'r', encoding='utf-8') as file:
    stopwords = set(file.read().splitlines())

# 去除停用词
words = [word for word in words if word not in stopwords and len(word.strip()) > 0]

# 使用 pandas 计算每个词的频率
word_freq = pd.Series(words).value_counts()

# 生成词云
wordcloud = WordCloud(width=800, height=400, font_path='simhei.ttf', background_color='white',max_words=100).generate_from_frequencies(word_freq)

# 显示词云
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 关闭坐标轴
plt.show()

# %%
word_freq[:30]
# Out:
# 周年      4932
# 玩家      3888
# 庆       3810
# 角色      3485
# 一周年     3037
# doge    2170
# 评论      2068
# 没有      2038
# 游戏      1840
# 心心      1610
# 大家      1583
# 非常      1494
# 福利      1469
# 加强      1429
# 简单明了    1388
# 清晰      1385
# 很       1299
# 心       1292
# 海       1274
# 喜欢      1263
# 藏狐      1233
# 生日      1152
# 米哈游     1129
# …       1085
# ＼       1065
# 小       1062
# 会       1061
# 专属      1053
# 后        986
# 看        958
# Name: count, dtype: int64
